# %%
from qdrant_client import QdrantClient

# %%
client = QdrantClient(
    url="http://localhost:6333")

# %%
from qdrant_client.models import VectorParams, Distance

# %%
if not client.collection_exists("my_collection"):
    print("Hi")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:122, in HTTPConnection._connect(self, request)
#     121 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122     stream = self._network_backend.connect_tcp(**kwargs)
#     123     trace.return_value = stream
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_backends/sync.py:205, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
# --> 205 with map_exceptions(exc_map):
#     206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#
# File /usr/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api_client.py:129, in ApiClient.send_inner(self, request)
#     128 try:
# --> 129     response = self._client.send(request)
#     130 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File /usr/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 if not client.collection_exists("my_collection"):
#       2     print("Hi")
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/qdrant_client.py:2240, in QdrantClient.collection_exists(self, collection_name, **kwargs)
#    2230 """Check whether collection already exists
#    2231
#    2232 Args:
#    (...)
#    2236     True if collection exists, False if not
#    2237 """
#    2238 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2240 return self._client.collection_exists(collection_name=collection_name, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/qdrant_remote.py:2597, in QdrantRemote.collection_exists(self, collection_name, **kwargs)
#    2591 if self._prefer_grpc:
#    2592     return self.grpc_collections.CollectionExists(
#    2593         grpc.CollectionExistsRequest(collection_name=collection_name),
#    2594         timeout=self._timeout,
#    2595     ).result.exists
# -> 2597 result: Optional[models.CollectionExistence] = self.http.collections_api.collection_exists(
#    2598     collection_name=collection_name
#    2599 ).result
#    2600 assert result is not None, "Collection exists returned None"
#    2601 return result.exists
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api/collections_api.py:281, in SyncCollectionsApi.collection_exists(self, collection_name)
#     274 def collection_exists(
#     275     self,
#     276     collection_name: str,
#     277 ) -> m.InlineResponse2007:
#     278     """
#     279     Returns \"true\" if the given collection name exists, and \"false\" otherwise
#     280     """
# --> 281     return self._build_for_collection_exists(
#     282         collection_name=collection_name,
#     283     )
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api/collections_api.py:67, in _CollectionsApi._build_for_collection_exists(self, collection_name)
#      62 path_params = {
#      63     "collection_name": str(collection_name),
#      64 }
#      66 headers = {}
# ---> 67 return self.api_client.request(
#      68     type_=m.InlineResponse2007,
#      69     method="GET",
#      70     url="/collections/{collection_name}/exists",
#      71     headers=headers if headers else None,
#      72     path_params=path_params,
#      73 )
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api_client.py:90, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      88     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      89 request = self._client.build_request(method, url, **kwargs)
# ---> 90 return self.send(request, type_)
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api_client.py:107, in ApiClient.send(self, request, type_)
#     106 def send(self, request: Request, type_: Type[T]) -> T:
# --> 107     response = self.middleware(request, self.send_inner)
#     109     if response.status_code == 429:
#     110         retry_after_s = response.headers.get("Retry-After", None)
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api_client.py:240, in BaseMiddleware.__call__(self, request, call_next)
#     239 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 240     return call_next(request)
#
# File ~/.local/lib/python3.10/site-packages/qdrant_client/http/api_client.py:131, in ApiClient.send_inner(self, request)
#     129     response = self._client.send(request)
#     130 except Exception as e:
# --> 131     raise ResponseHandlingException(e)
#     132 return response
#
# ResponseHandlingException: [Errno 111] Connection refused

# %%
kriszti = 1000
zsigi = 6808

# %%
import time

time.time()
# Out:
# 1745933908.7347696
